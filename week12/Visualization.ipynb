# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
plt.plot([0,1], [0,1])
plt.title('한글 연습')
plt.show()

# %%
import numpy as np
import pandas as pd

crime_raw_data = pd.read_csv('2018년.csv', encoding = 'euc-kr')
crime_raw_data.head()
# Out:
#    구분  죄종 발생검거   건수
# 0  중부  살인   발생    1
# 1  중부  살인   검거    1
# 2  중부  강도   발생    5
# 3  중부  강도   검거    7
# 4  중부  강간   발생  132

# %%
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 9.8+ KB

# %%
crime_raw_data['죄종'].unique()
# Out:
# array(['살인', '강도', '강간', '절도', '폭력'], dtype=object)

# %%
crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index = ['구분'], columns = ['죄종', '발생검거'], aggfunc = np.sum
)

crime_station.head()
# Out:
#        건수
# 죄종     강간       강도     살인        절도          폭력
# 발생검거   검거   발생  검거  발생 검거  발생    검거    발생    검거    발생
# 구분
# 강남    352  406   8   9  8   5   836  2020  1890  2188
# 강동    143  170   7   7  3   3   765  1515  1871  2224
# 강북    135  188   7   7  6   8   603  1112  1992  2122
# 강서    246  269   3   6  9  11   982  1724  2229  2619
# 관악    305  352  12  10  9   9  1025  2012  2302  2643

# %%
crime_station.columns
# Out:
# MultiIndex([('건수', '강간', '검거'),
#             ('건수', '강간', '발생'),
#             ('건수', '강도', '검거'),
#             ('건수', '강도', '발생'),
#             ('건수', '살인', '검거'),
#             ('건수', '살인', '발생'),
#             ('건수', '절도', '검거'),
#             ('건수', '절도', '발생'),
#             ('건수', '폭력', '검거'),
#             ('건수', '폭력', '발생')],
#            names=[None, '죄종', '발생검거'])

# %%
crime_station.columns = crime_station.columns.droplevel([0])
crime_station.columns
# Out:
# MultiIndex([('강간', '검거'),
#             ('강간', '발생'),
#             ('강도', '검거'),
#             ('강도', '발생'),
#             ('살인', '검거'),
#             ('살인', '발생'),
#             ('절도', '검거'),
#             ('절도', '발생'),
#             ('폭력', '검거'),
#             ('폭력', '발생')],
#            names=['죄종', '발생검거'])

# %%
crime_station['강도', '검거']
# Out:
# 구분
# 강남      8
# 강동      7
# 강북      7
# 강서      3
# 관악     12
# 광진      1
# 구로      9
# 금천      6
# 남대문     4
# 노원      5
# 도봉      3
# 동대문     4
# 동작      7
# 마포      7
# 방배      1
# 서대문     3
# 서부      0
# 서초      4
# 성동      8
# 성북      0
# 송파      8
# 수서      2
# 양천     14
# 영등포     6
# 용산      2
# 은평      1
# 종로      0
# 종암      2
# 중랑      3
# 중부      7
# 혜화      2
# Name: (강도, 검거), dtype: int64

# %%
crime_station['살인', '발생']
# Out:
# 구분
# 강남      5
# 강동      3
# 강북      8
# 강서     11
# 관악      9
# 광진      7
# 구로      8
# 금천      6
# 남대문     1
# 노원      5
# 도봉      1
# 동대문     2
# 동작      3
# 마포      6
# 방배      0
# 서대문     5
# 서부      4
# 서초      5
# 성동      2
# 성북      1
# 송파      5
# 수서      5
# 양천      2
# 영등포    17
# 용산      1
# 은평      4
# 종로      5
# 종암      6
# 중랑      4
# 중부      1
# 혜화      1
# Name: (살인, 발생), dtype: int64

# %%
crime_station.loc['강남', ('강도', '발생')]
# Out:
# 9

# %%
crime_station.head()
# Out:
# 죄종     강간       강도     살인        절도          폭력
# 발생검거   검거   발생  검거  발생 검거  발생    검거    발생    검거    발생
# 구분
# 강남    352  406   8   9  8   5   836  2020  1890  2188
# 강동    143  170   7   7  3   3   765  1515  1871  2224
# 강북    135  188   7   7  6   8   603  1112  1992  2122
# 강서    246  269   3   6  9  11   982  1724  2229  2619
# 관악    305  352  12  10  9   9  1025  2012  2302  2643

# %%
tmp = crime_station.columns.get_level_values(0) + \
crime_station.columns.get_level_values(1)

tmp
# Out:
# Index(['강간검거', '강간발생', '강도검거', '강도발생', '살인검거', '살인발생', '절도검거', '절도발생', '폭력검거',
#        '폭력발생'],
#       dtype='object')

# %%
crime_station.columns = tmp
crime_station.head()
# Out:
#     강간검거  강간발생  강도검거  강도발생  살인검거  살인발생  절도검거  절도발생  폭력검거  폭력발생
# 구분
# 강남   352   406     8     9     8     5   836  2020  1890  2188
# 강동   143   170     7     7     3     3   765  1515  1871  2224
# 강북   135   188     7     7     6     8   603  1112  1992  2122
# 강서   246   269     3     6     9    11   982  1724  2229  2619
# 관악   305   352    12    10     9     9  1025  2012  2302  2643

# %%
crime_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 강남 to 혜화
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강간검거    31 non-null     int64
#  1   강간발생    31 non-null     int64
#  2   강도검거    31 non-null     int64
#  3   강도발생    31 non-null     int64
#  4   살인검거    31 non-null     int64
#  5   살인발생    31 non-null     int64
#  6   절도검거    31 non-null     int64
#  7   절도발생    31 non-null     int64
#  8   폭력검거    31 non-null     int64
#  9   폭력발생    31 non-null     int64
# dtypes: int64(10)
# memory usage: 3.7+ KB

# %%
real_gu = {'종로구' : ['종로', '혜화'], '중구' : ['남대문', '중부'],
           '용산구' : ['용산'], '성동구' : ['성동'],
           '광진구' : ['광진'], '동대문구' : ['동대문'],
           '중랑구' : ['중랑'], '성북구' : ['성북', '종암'],
           '강북구' : ['강북'], '도봉구' : ['도봉'],
           '노원구' : ['노원'], '은평구' : ['서부', '은평'],
           '서대문구' : ['서대문'], '마포구' : ['마포'],
           '양천구' : ['양천'], '강서구' : ['강서'],
           '구로구' : ['구로'], '금천구' : ['금천'],
           '영등포구' : ['영등포'], '동작구' : ['동작'],
           '관악구' : ['관악'], '서초구' : ['방배', '서초'],
           '강남구' : ['강남', '수서'], '송파구' : ['송파'],
           '강동구' : ['강동']}

# %%
for gu_name, station_name in real_gu.items():
    if '강남' in station_name:
        print(gu_name)
# Out:
# 강남구

# %%
tmp_gu = []

for station in crime_station.index:
    for gu_name, station_name in real_gu.items():
        if station in station_name:
            tmp_gu.append(gu_name)

tmp_gu
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '중구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서초구',
#  '서대문구',
#  '은평구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '강남구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '성북구',
#  '중랑구',
#  '중구',
#  '종로구']

# %%
crime_station['구'] = tmp_gu
crime_station
# Out:
#      강간검거  강간발생  강도검거  강도발생  살인검거  살인발생  절도검거  절도발생  폭력검거  폭력발생     구
# 구분
# 강남    352   406     8     9     8     5   836  2020  1890  2188   강남구
# 강동    143   170     7     7     3     3   765  1515  1871  2224   강동구
# 강북    135   188     7     7     6     8   603  1112  1992  2122   강북구
# 강서    246   269     3     6     9    11   982  1724  2229  2619   강서구
# 관악    305   352    12    10     9     9  1025  2012  2302  2643   관악구
# 광진    184   229     1     2     5     7   974  1769  1625  1908   광진구
# 구로    181   250     9     9     8     8   787  1717  2353  2826   구로구
# 금천    185   200     6     7     6     6   645  1168  1725  1912   금천구
# 남대문    52    75     4     6     1     1   417   798   709   779    중구
# 노원    173   194     5     5     4     5   585  1422  1958  2381   노원구
# 도봉    117   113     3     5     1     1   431   781  1124  1349   도봉구
# 동대문   112   145     4     5     2     2   930  1447  1920  2081  동대문구
# 동작    154   288     7     7     3     3   532  1151  1394  1651   동작구
# 마포    396   473     7     6     6     6   882  2011  2278  2676   마포구
# 방배     41    63     1     1     0     0   165   369   423   487   서초구
# 서대문   189   206     3     3     4     5   585  1062  1235  1526  서대문구
# 서부     52    58     0     0     4     4   325   505   711   807   은평구
# 서초    274   407     4     4     5     5   673  1482  1597  1908   서초구
# 성동    102   126     8     5     2     2   487   999  1188  1325   성동구
# 성북     90   125     0     0     1     1   298   600   798   886   성북구
# 송파    254   309     8     6     6     5  1034  2352  2749  3135   송파구
# 수서    171   194     2     5     5     5   481   984  1443  1697   강남구
# 양천    111   120    14     4     3     2   646  1384  1685  2005   양천구
# 영등포   267   391     6     8    15    17  1064  2292  2570  3132  영등포구
# 용산    285   331     2     3     1     1   522  1096  1733  1980   용산구
# 은평    117   130     1     1     4     4   491   773  1158  1308   은평구
# 종로    114   136     0     1     4     5   398   744   993  1131   종로구
# 종암     50    58     2     1     5     6   337   564   696   801   성북구
# 중랑    145   174     3     3     5     4   876  1526  2193  2581   중랑구
# 중부     63   132     7     5     1     1   415  1057  1010  1176    중구
# 혜화     58   100     2     2     1     1   340   739   712   831   종로구

# %%
crime_gu = pd.pivot_table(crime_station, index = '구', aggfunc = np.sum)
crime_gu.head()
# Out:
#      강간검거  강간발생  강도검거  강도발생  살인검거  살인발생  절도검거  절도발생  폭력검거  폭력발생
# 구
# 강남구   523   600    10    14    13    10  1317  3004  3333  3885
# 강동구   143   170     7     7     3     3   765  1515  1871  2224
# 강북구   135   188     7     7     6     8   603  1112  1992  2122
# 강서구   246   269     3     6     9    11   982  1724  2229  2619
# 관악구   305   352    12    10     9     9  1025  2012  2302  2643

# %%
crime_gu['살인발생'].sort_values(ascending = False).head()
# Out:
# 구
# 영등포구    17
# 강서구     11
# 강남구     10
# 관악구      9
# 강북구      8
# Name: 살인발생, dtype: int64

# %%
crime_gu['폭력발생'].sort_values(ascending = False).head()
# Out:
# 구
# 강남구     3885
# 송파구     3135
# 영등포구    3132
# 구로구     2826
# 마포구     2676
# Name: 폭력발생, dtype: int64

# %%
crime_gu['강도발생'].sort_values(ascending = False).head()
# Out:
# 구
# 강남구     14
# 중구      11
# 관악구     10
# 구로구      9
# 영등포구     8
# Name: 강도발생, dtype: int64

# %%
crime_gu['절도발생'].sort_values(ascending = False).head()
# Out:
# 구
# 강남구     3004
# 송파구     2352
# 영등포구    2292
# 관악구     2012
# 마포구     2011
# Name: 절도발생, dtype: int64

# %%
crime_gu['강간발생'].sort_values(ascending = False).head()
# Out:
# 구
# 강남구     600
# 마포구     473
# 서초구     470
# 영등포구    391
# 관악구     352
# Name: 강간발생, dtype: int64

# %%
crime_gu['강도검거']/crime_gu['강도발생']
# Out:
# 구
# 강남구     0.714286
# 강동구     1.000000
# 강북구     1.000000
# 강서구     0.500000
# 관악구     1.200000
# 광진구     0.500000
# 구로구     1.000000
# 금천구     0.857143
# 노원구     1.000000
# 도봉구     0.600000
# 동대문구    0.800000
# 동작구     1.000000
# 마포구     1.166667
# 서대문구    1.000000
# 서초구     1.000000
# 성동구     1.600000
# 성북구     2.000000
# 송파구     1.333333
# 양천구     3.500000
# 영등포구    0.750000
# 용산구     0.666667
# 은평구     1.000000
# 종로구     0.666667
# 중구      1.000000
# 중랑구     1.000000
# dtype: float64

# %%
num = ['강간검거', '강도검거', '살인검거', '절도검거', '폭력검거']
den = ['강간발생', '강도발생', '살인발생', '절도발생', '폭력발생']

crime_gu[num].div(crime_gu[den].values)
# Out:
#           강간검거      강도검거      살인검거      절도검거      폭력검거
# 구
# 강남구   0.871667  0.714286  1.300000  0.438415  0.857915
# 강동구   0.841176  1.000000  1.000000  0.504950  0.841277
# 강북구   0.718085  1.000000  0.750000  0.542266  0.938737
# 강서구   0.914498  0.500000  0.818182  0.569606  0.851088
# 관악구   0.866477  1.200000  1.000000  0.509443  0.870980
# 광진구   0.803493  0.500000  0.714286  0.550594  0.851677
# 구로구   0.724000  1.000000  1.000000  0.458358  0.832626
# 금천구   0.925000  0.857143  1.000000  0.552226  0.902197
# 노원구   0.891753  1.000000  0.800000  0.411392  0.822344
# 도봉구   1.035398  0.600000  1.000000  0.551857  0.833210
# 동대문구  0.772414  0.800000  1.000000  0.642709  0.922633
# 동작구   0.534722  1.000000  1.000000  0.462207  0.844337
# 마포구   0.837209  1.166667  1.000000  0.438588  0.851271
# 서대문구  0.917476  1.000000  0.800000  0.550847  0.809305
# 서초구   0.670213  1.000000  1.000000  0.452728  0.843424
# 성동구   0.809524  1.600000  1.000000  0.487487  0.896604
# 성북구   0.765027  2.000000  0.857143  0.545533  0.885596
# 송파구   0.822006  1.333333  1.200000  0.439626  0.876874
# 양천구   0.925000  3.500000  1.500000  0.466763  0.840399
# 영등포구  0.682864  0.750000  0.882353  0.464223  0.820562
# 용산구   0.861027  0.666667  1.000000  0.476277  0.875253
# 은평구   0.898936  1.000000  1.000000  0.638498  0.883688
# 종로구   0.728814  0.666667  0.833333  0.497640  0.869011
# 중구    0.555556  1.000000  1.000000  0.448518  0.879284
# 중랑구   0.833333  1.000000  1.250000  0.574050  0.849671

# %%
target = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

crime_gu[target] = crime_gu[num].div(crime_gu[den].values) * 100
crime_gu.head()
# Out:
#      강간검거  강간발생  강도검거  강도발생  살인검거  살인발생  절도검거  절도발생  폭력검거  폭력발생      강간검거율  \
# 구
# 강남구   523   600    10    14    13    10  1317  3004  3333  3885  87.166667
# 강동구   143   170     7     7     3     3   765  1515  1871  2224  84.117647
# 강북구   135   188     7     7     6     8   603  1112  1992  2122  71.808511
# 강서구   246   269     3     6     9    11   982  1724  2229  2619  91.449814
# 관악구   305   352    12    10     9     9  1025  2012  2302  2643  86.647727
#
#           강도검거율       살인검거율      절도검거율      폭력검거율
# 구
# 강남구   71.428571  130.000000  43.841545  85.791506
# 강동구  100.000000  100.000000  50.495050  84.127698
# 강북구  100.000000   75.000000  54.226619  93.873704
# 강서구   50.000000   81.818182  56.960557  85.108820
# 관악구  120.000000  100.000000  50.944334  87.097995

# %%
crime_gu = crime_gu.drop(columns = num)
crime_gu.head()
# Out:
#      강간발생  강도발생  살인발생  절도발생  폭력발생      강간검거율       강도검거율       살인검거율  \
# 구
# 강남구   600    14    10  3004  3885  87.166667   71.428571  130.000000
# 강동구   170     7     3  1515  2224  84.117647  100.000000  100.000000
# 강북구   188     7     8  1112  2122  71.808511  100.000000   75.000000
# 강서구   269     6    11  1724  2619  91.449814   50.000000   81.818182
# 관악구   352    10     9  2012  2643  86.647727  120.000000  100.000000
#
#          절도검거율      폭력검거율
# 구
# 강남구  43.841545  85.791506
# 강동구  50.495050  84.127698
# 강북구  54.226619  93.873704
# 강서구  56.960557  85.108820
# 관악구  50.944334  87.097995

# %%
crime_gu[target] > 100
# Out:
#       강간검거율  강도검거율  살인검거율  절도검거율  폭력검거율
# 구
# 강남구   False  False   True  False  False
# 강동구   False  False  False  False  False
# 강북구   False  False  False  False  False
# 강서구   False  False  False  False  False
# 관악구   False   True  False  False  False
# 광진구   False  False  False  False  False
# 구로구   False  False  False  False  False
# 금천구   False  False  False  False  False
# 노원구   False  False  False  False  False
# 도봉구    True  False  False  False  False
# 동대문구  False  False  False  False  False
# 동작구   False  False  False  False  False
# 마포구   False   True  False  False  False
# 서대문구  False  False  False  False  False
# 서초구   False  False  False  False  False
# 성동구   False   True  False  False  False
# 성북구   False   True  False  False  False
# 송파구   False   True   True  False  False
# 양천구   False   True   True  False  False
# 영등포구  False  False  False  False  False
# 용산구   False  False  False  False  False
# 은평구   False  False  False  False  False
# 종로구   False  False  False  False  False
# 중구    False  False  False  False  False
# 중랑구   False  False   True  False  False

# %%
crime_gu[crime_gu[target] > 100] = 100
crime_gu
# Out:
#       강간발생  강도발생  살인발생  절도발생  폭력발생       강간검거율       강도검거율       살인검거율  \
# 구
# 강남구    600    14    10  3004  3885   87.166667   71.428571  100.000000
# 강동구    170     7     3  1515  2224   84.117647  100.000000  100.000000
# 강북구    188     7     8  1112  2122   71.808511  100.000000   75.000000
# 강서구    269     6    11  1724  2619   91.449814   50.000000   81.818182
# 관악구    352    10     9  2012  2643   86.647727  100.000000  100.000000
# 광진구    229     2     7  1769  1908   80.349345   50.000000   71.428571
# 구로구    250     9     8  1717  2826   72.400000  100.000000  100.000000
# 금천구    200     7     6  1168  1912   92.500000   85.714286  100.000000
# 노원구    194     5     5  1422  2381   89.175258  100.000000   80.000000
# 도봉구    113     5     1   781  1349  100.000000   60.000000  100.000000
# 동대문구   145     5     2  1447  2081   77.241379   80.000000  100.000000
# 동작구    288     7     3  1151  1651   53.472222  100.000000  100.000000
# 마포구    473     6     6  2011  2676   83.720930  100.000000  100.000000
# 서대문구   206     3     5  1062  1526   91.747573  100.000000   80.000000
# 서초구    470     5     5  1851  2395   67.021277  100.000000  100.000000
# 성동구    126     5     2   999  1325   80.952381  100.000000  100.000000
# 성북구    183     1     7  1164  1687   76.502732  100.000000   85.714286
# 송파구    309     6     5  2352  3135   82.200647  100.000000  100.000000
# 양천구    120     4     2  1384  2005   92.500000  100.000000  100.000000
# 영등포구   391     8    17  2292  3132   68.286445   75.000000   88.235294
# 용산구    331     3     1  1096  1980   86.102719   66.666667  100.000000
# 은평구    188     1     8  1278  2115   89.893617  100.000000  100.000000
# 종로구    236     3     6  1483  1962   72.881356   66.666667   83.333333
# 중구     207    11     2  1855  1955   55.555556  100.000000  100.000000
# 중랑구    174     3     4  1526  2581   83.333333  100.000000  100.000000
#
#           절도검거율      폭력검거율
# 구
# 강남구   43.841545  85.791506
# 강동구   50.495050  84.127698
# 강북구   54.226619  93.873704
# 강서구   56.960557  85.108820
# 관악구   50.944334  87.097995
# 광진구   55.059356  85.167715
# 구로구   45.835760  83.262562
# 금천구   55.222603  90.219665
# 노원구   41.139241  82.234355
# 도봉구   55.185659  83.320979
# 동대문구  64.270905  92.263335
# 동작구   46.220678  84.433677
# 마포구   43.858777  85.127055
# 서대문구  55.084746  80.930537
# 서초구   45.272825  84.342380
# 성동구   48.748749  89.660377
# 성북구   54.553265  88.559573
# 송파구   43.962585  87.687400
# 양천구   46.676301  84.039900
# 영등포구  46.422339  82.056194
# 용산구   47.627737  87.525253
# 은평구   63.849765  88.368794
# 종로구   49.763992  86.901121
# 중구    44.851752  87.928389
# 중랑구   57.404980  84.967067

# %%
crime_gu.rename(columns = {'강간발생' : '강간',
                           '강도발생' : '강도',
                           '살인발생' : '살인',
                           '절도발생' : '절도',
                           '폭력발생' : '폭력'},
                inplace = True)
crime_gu.head()
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구
# 강남구  600  14  10  3004  3885  87.166667   71.428571  100.000000  43.841545
# 강동구  170   7   3  1515  2224  84.117647  100.000000  100.000000  50.495050
# 강북구  188   7   8  1112  2122  71.808511  100.000000   75.000000  54.226619
# 강서구  269   6  11  1724  2619  91.449814   50.000000   81.818182  56.960557
# 관악구  352  10   9  2012  2643  86.647727  100.000000  100.000000  50.944334
#
#          폭력검거율
# 구
# 강남구  85.791506
# 강동구  84.127698
# 강북구  93.873704
# 강서구  85.108820
# 관악구  87.097995

# %%
col = ['살인', '강도', '강간', '절도', '폭력']
crime_gu_norm = crime_gu[col] / crime_gu[col].max()
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력
# 구
# 강남구  0.588235  1.000000  1.000000  1.000000  1.000000
# 강동구  0.176471  0.500000  0.283333  0.504328  0.572458
# 강북구  0.470588  0.500000  0.313333  0.370173  0.546203
# 강서구  0.647059  0.428571  0.448333  0.573901  0.674131
# 관악구  0.529412  0.714286  0.586667  0.669774  0.680309

# %%
col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_gu_norm[col2] = crime_gu[col2]
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.588235  1.000000  1.000000  1.000000  1.000000  87.166667   71.428571
# 강동구  0.176471  0.500000  0.283333  0.504328  0.572458  84.117647  100.000000
# 강북구  0.470588  0.500000  0.313333  0.370173  0.546203  71.808511  100.000000
# 강서구  0.647059  0.428571  0.448333  0.573901  0.674131  91.449814   50.000000
# 관악구  0.529412  0.714286  0.586667  0.669774  0.680309  86.647727  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구
# 강남구  100.000000  43.841545  85.791506
# 강동구  100.000000  50.495050  84.127698
# 강북구   75.000000  54.226619  93.873704
# 강서구   81.818182  56.960557  85.108820
# 관악구  100.000000  50.944334  87.097995

# %%
crime_gu_norm['범죄'] = np.mean(crime_gu_norm[col], axis = 1)
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.588235  1.000000  1.000000  1.000000  1.000000  87.166667   71.428571
# 강동구  0.176471  0.500000  0.283333  0.504328  0.572458  84.117647  100.000000
# 강북구  0.470588  0.500000  0.313333  0.370173  0.546203  71.808511  100.000000
# 강서구  0.647059  0.428571  0.448333  0.573901  0.674131  91.449814   50.000000
# 관악구  0.529412  0.714286  0.586667  0.669774  0.680309  86.647727  100.000000
#
#           살인검거율      절도검거율      폭력검거율        범죄
# 구
# 강남구  100.000000  43.841545  85.791506  0.917647
# 강동구  100.000000  50.495050  84.127698  0.407318
# 강북구   75.000000  54.226619  93.873704  0.440060
# 강서구   81.818182  56.960557  85.108820  0.554399
# 관악구  100.000000  50.944334  87.097995  0.636089

# %%
crime_gu_norm['범죄'].sort_values(ascending = False).head()
# Out:
# 구
# 강남구     0.917647
# 영등포구    0.758451
# 관악구     0.636089
# 마포구     0.585618
# 구로구     0.565819
# Name: 범죄, dtype: float64

# %%
crime_gu_norm['검거'] = np.mean(crime_gu_norm[col2], axis = 1)
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.588235  1.000000  1.000000  1.000000  1.000000  87.166667   71.428571
# 강동구  0.176471  0.500000  0.283333  0.504328  0.572458  84.117647  100.000000
# 강북구  0.470588  0.500000  0.313333  0.370173  0.546203  71.808511  100.000000
# 강서구  0.647059  0.428571  0.448333  0.573901  0.674131  91.449814   50.000000
# 관악구  0.529412  0.714286  0.586667  0.669774  0.680309  86.647727  100.000000
#
#           살인검거율      절도검거율      폭력검거율        범죄         검거
# 구
# 강남구  100.000000  43.841545  85.791506  0.917647  77.645658
# 강동구  100.000000  50.495050  84.127698  0.407318  83.748079
# 강북구   75.000000  54.226619  93.873704  0.440060  78.981767
# 강서구   81.818182  56.960557  85.108820  0.554399  73.067475
# 관악구  100.000000  50.944334  87.097995  0.636089  84.938011

# %%
crime_gu_norm['검거'].sort_values(ascending = False).head()
# Out:
# 구
# 은평구    88.422435
# 중랑구    85.141076
# 관악구    84.938011
# 금천구    84.731311
# 양천구    84.643240
# Name: 검거, dtype: float64

# %%
crime_gu_norm['검거'].sort_values().head()
# Out:
# 구
# 광진구     68.400997
# 종로구     71.909294
# 영등포구    72.000054
# 강서구     73.067475
# 동작구     76.825315
# Name: 검거, dtype: float64

# %%
import seaborn as sns

target_col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율', '검거']

crime_gu_norm_sort = crime_gu_norm.sort_values(by = '검거', ascending = False)

plt.figure(figsize = (10, 10))
sns.heatmap(crime_gu_norm_sort[target_col],
            annot = True, fmt = 'f', linewidth = .5, cmap = 'RdPu')
plt.title('범죄 검거 비율 (정규화된 검거의 합으로 정렬)')
plt.show()

# %%
target_col = ['강간', '강도', '살인', '절도', '폭력', '범죄']

crime_gu_norm_sort = crime_gu_norm.sort_values(by = '범죄', ascending = False)

plt.figure(figsize = (10, 10))
sns.heatmap(crime_gu_norm_sort[target_col],
            annot = True, fmt = 'f', linewidth = .5, cmap = 'RdPu')
plt.title('범죄 비율 (정규화된 발생 건수로 정렬)')
plt.show()

# %%
import folium

m = folium.Map(location=[45.5236, -122.6750])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7c75d25b02459e09af61df7e5e1fc32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7c75d25b02459e09af61df7e5e1fc32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7c75d25b02459e09af61df7e5e1fc32 = L.map(
#                 &quot;map_b7c75d25b02459e09af61df7e5e1fc32&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcd1d13a7082cef38a18b674c07bd71c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7c75d25b02459e09af61df7e5e1fc32);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location = [22.20111, 113.54417], tiles = 'OpenStreetMap', zoom_start = 13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe3d5977f04581f12f1da14a1f95e44d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe3d5977f04581f12f1da14a1f95e44d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe3d5977f04581f12f1da14a1f95e44d = L.map(
#                 &quot;map_fe3d5977f04581f12f1da14a1f95e44d&quot;,
#                 {
#                     center: [22.20111, 113.54417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23c870c8f28bed471b66889bd8e089d5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe3d5977f04581f12f1da14a1f95e44d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location = [22.20111, 113.54417], tiles = 'Cartodb dark_matter', zoom_start = 13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_078195e29f53f3198d1a9c55ffba03b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_078195e29f53f3198d1a9c55ffba03b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_078195e29f53f3198d1a9c55ffba03b3 = L.map(
#                 &quot;map_078195e29f53f3198d1a9c55ffba03b3&quot;,
#                 {
#                     center: [22.20111, 113.54417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7460eb8689ebf4358706dc6113b4d46a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_078195e29f53f3198d1a9c55ffba03b3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map = folium.Map(location = [45.372, -121.6972], zoom_start = 12)

folium.Marker([45.3288, -121.6625],
              popup = '<i>Mt. Hood Meadows</i>').add_to(my_map)
folium.Marker([45.3311, -121.7113],
              popup = '<b>Timberline Lodge</b>').add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c34e8b204ad090636f9dd953f0096ee0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c34e8b204ad090636f9dd953f0096ee0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c34e8b204ad090636f9dd953f0096ee0 = L.map(
#                 &quot;map_c34e8b204ad090636f9dd953f0096ee0&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad4f9368423bff56425323c3523722a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c34e8b204ad090636f9dd953f0096ee0);
#
#
#             var marker_8d3e460e5cc03e1467e11a8db37395be = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_c34e8b204ad090636f9dd953f0096ee0);
#
#
#         var popup_8cc50b243a08e9cce355685db75dd0a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03c98981ca29304e2118678b944ff27c = $(`&lt;div id=&quot;html_03c98981ca29304e2118678b944ff27c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_8cc50b243a08e9cce355685db75dd0a6.setContent(html_03c98981ca29304e2118678b944ff27c);
#
#
#
#         marker_8d3e460e5cc03e1467e11a8db37395be.bindPopup(popup_8cc50b243a08e9cce355685db75dd0a6)
#         ;
#
#
#
#
#             var marker_0ebc20c8b380656015479f535ac280fb = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_c34e8b204ad090636f9dd953f0096ee0);
#
#
#         var popup_321b960a99270eea599dfd4c75a3de6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d151193c0e3568da8fddf0810cf2d203 = $(`&lt;div id=&quot;html_d151193c0e3568da8fddf0810cf2d203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Timberline Lodge&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_321b960a99270eea599dfd4c75a3de6d.setContent(html_d151193c0e3568da8fddf0810cf2d203);
#
#
#
#         marker_0ebc20c8b380656015479f535ac280fb.bindPopup(popup_321b960a99270eea599dfd4c75a3de6d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json

geo_str = json.load(open('./skorea_municipalities_geo_simple.json', encoding = 'utf-8'))
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
#       [127.1116764203608, 37.540669955324965],
#       [127.12123165719615, 37.52528270089],
#       [127.14672806823502, 37.51415680680291],
#       [127.1634944215765, 37.497445406097484],
#       [127.14206058413274, 37.47089819098501],
#       [127.12440571080893, 37.46240445587048],
#       [127.11117085201238, 37.485708381512445],
#       [127.0719146000724, 37.50224013587669],
#       [127.0690698130372, 37.522279423505026]]]}},
#   {'type': 'Feature',
#    'id': '강남구',
#    'properties': {'code': '11230',
#     'name': '강남구',
#     'name_eng': 'Gangnam-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.05867359288398, 37.52629974922568],
#       [127.0690698130372, 37.522279423505026],
#       [127.0719146000724, 37.50224013587669],
#       [127.11117085201238, 37.485708381512445],
#       [127.12440571080893, 37.46240445587048],
#       [127.09842759318751, 37.45862253857461],
#       [127.08640440578156, 37.472697935184655],
#       [127.0559170481904, 37.4659228914077],
#       [127.03621915098798, 37.48175802427603],
#       [127.01397119667513, 37.52503988289669],
#       [127.02302831890559, 37.53231899582663],
#       [127.05867359288398, 37.52629974922568]]]}},
#   {'type': 'Feature',
#    'id': '서초구',
#    'properties': {'code': '11220',
#     'name': '서초구',
#     'name_eng': 'Seocho-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.01397119667513, 37.52503988289669],
#       [127.03621915098798, 37.48175802427603],
#       [127.0559170481904, 37.4659228914077],
#       [127.08640440578156, 37.472697935184655],
#       [127.09842759318751, 37.45862253857461],
#       [127.09046928565951, 37.44296826114185],
#       [127.06778107605433, 37.426197424057314],
#       [127.04957232987142, 37.42805836845694],
#       [127.03881782597922, 37.45382039851715],
#       [126.99072073195462, 37.455326143310025],
#       [126.98367668291802, 37.473856492692086],
#       [126.98223807916081, 37.509314966770326],
#       [127.01397119667513, 37.52503988289669]]]}},
#   {'type': 'Feature',
#    'id': '관악구',
#    'properties': {'code': '11210',
#     'name': '관악구',
#     'name_eng': 'Gwanak-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.98367668291802, 37.473856492692086],
#       [126.99072073195462, 37.455326143310025],
#       [126.96520439085143, 37.438249784006246],
#       [126.95000001010182, 37.43613451165719],
#       [126.93084408056525, 37.447382928333994],
#       [126.9167728146601, 37.45490566423789],
#       [126.90156094129895, 37.47753842789901],
#       [126.90531975801812, 37.48218087575429],
#       [126.94922661389508, 37.49125437495649],
#       [126.9725891850662, 37.472561363278125],
#       [126.98367668291802, 37.473856492692086]]]}},
#   {'type': 'Feature',
#    'id': '동작구',
#    'properties': {'code': '11200',
#     'name': '동작구',
#     'name_eng': 'Dongjak-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.98223807916081, 37.509314966770326],
#       [126.98367668291802, 37.473856492692086],
#       [126.9725891850662, 37.472561363278125],
#       [126.94922661389508, 37.49125437495649],
#       [126.90531975801812, 37.48218087575429],
#       [126.92177893174825, 37.494889877415176],
#       [126.92810628828279, 37.51329595732015],
#       [126.95249990298159, 37.51722500741813],
#       [126.98223807916081, 37.509314966770326]]]}},
#   {'type': 'Feature',
#    'id': '영등포구',
#    'properties': {'code': '11190',
#     'name': '영등포구',
#     'name_eng': 'Yeongdeungpo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.89184663862764, 37.547373974997114],
#       [126.94566733083212, 37.526617542453366],
#       [126.95249990298159, 37.51722500741813],
#       [126.92810628828279, 37.51329595732015],
#       [126.92177893174825, 37.494889877415176],
#       [126.90531975801812, 37.48218087575429],
#       [126.89594776782485, 37.504675281309176],
#       [126.88156402353862, 37.513970034765684],
#       [126.88825757860099, 37.54079733630232],
#       [126.89184663862764, 37.547373974997114]]]}},
#   {'type': 'Feature',
#    'id': '금천구',
#    'properties': {'code': '11180',
#     'name': '금천구',
#     'name_eng': 'Geumcheon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.90156094129895, 37.47753842789901],
#       [126.9167728146601, 37.45490566423789],
#       [126.93084408056525, 37.447382928333994],
#       [126.9025831711697, 37.434549366349124],
#       [126.87683271502428, 37.482576591607305],
#       [126.90156094129895, 37.47753842789901]]]}},
#   {'type': 'Feature',
#    'id': '구로구',
#    'properties': {'code': '11170',
#     'name': '구로구',
#     'name_eng': 'Guro-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.82688081517314, 37.50548972232896],
#       [126.88156402353862, 37.513970034765684],
#       [126.89594776782485, 37.504675281309176],
#       [126.90531975801812, 37.48218087575429],
#       [126.90156094129895, 37.47753842789901],
#       [126.87683271502428, 37.482576591607305],
#       [126.84762676054953, 37.47146723936323],
#       [126.83549485076196, 37.474098236975095],
#       [126.82264796791348, 37.4878476492147],
#       [126.82504736331406, 37.50302612640443],
#       [126.82688081517314, 37.50548972232896]]]}},
#   {'type': 'Feature',
#    'id': '강서구',
#    'properties': {'code': '11160',
#     'name': '강서구',
#     'name_eng': 'Gangseo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.79575768552907, 37.57881087633202],
#       [126.80702115023597, 37.60123001013228],
#       [126.82251438477105, 37.5880430810082],
#       [126.85984199399667, 37.571847855292745],
#       [126.89184663862764, 37.547373974997114],
#       [126.88825757860099, 37.54079733630232],
#       [126.86637464321238, 37.54859191094823],
#       [126.86610073476395, 37.52699964144669],
#       [126.84257291943153, 37.52373707805596],
#       [126.8242331426722, 37.53788078753248],
#       [126.77324417717703, 37.5459123450554],
#       [126.76979180579352, 37.55139183008809],
#       [126.79575768552907, 37.57881087633202]]]}},
#   {'type': 'Feature',
#    'id': '양천구',
#    'properties': {'code': '11150',
#     'name': '양천구',
#     'name_eng': 'Yangcheon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.8242331426722, 37.53788078753248],
#       [126.84257291943153, 37.52373707805596],
#       [126.86610073476395, 37.52699964144669],
#       [126.86637464321238, 37.54859191094823],
#       [126.88825757860099, 37.54079733630232],
#       [126.88156402353862, 37.513970034765684],
#       [126.82688081517314, 37.50548972232896],
#       [126.8242331426722, 37.53788078753248]]]}},
#   {'type': 'Feature',
#    'id': '마포구',
#    'properties': {'code': '11140',
#     'name': '마포구',
#     'name_eng': 'Mapo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.90522065831053, 37.57409700522574],
#       [126.93898161798973, 37.552310003728124],
#       [126.96358226710812, 37.55605635475154],
#       [126.96448570553055, 37.548705692021635],
#       [126.94566733083212, 37.526617542453366],
#       [126.89184663862764, 37.547373974997114],
#       [126.85984199399667, 37.571847855292745],
#       [126.88433284773288, 37.588143322880526],
#       [126.90522065831053, 37.57409700522574]]]}},
#   {'type': 'Feature',
#    'id': '서대문구',
#    'properties': {'code': '11130',
#     'name': '서대문구',
#     'name_eng': 'Seodaemun-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9524752030572, 37.60508692737045],
#       [126.95565425846463, 37.576080790881456],
#       [126.96873633279075, 37.56313604690827],
#       [126.96358226710812, 37.55605635475154],
#       [126.93898161798973, 37.552310003728124],
#       [126.90522065831053, 37.57409700522574],
#       [126.9524752030572, 37.60508692737045]]]}},
#   {'type': 'Feature',
#    'id': '은평구',
#    'properties': {'code': '11120',
#     'name': '은평구',
#     'name_eng': 'Eunpyeong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.95427017006129, 37.622033431339425],
#       [126.9524752030572, 37.60508692737045],
#       [126.90522065831053, 37.57409700522574],
#       [126.88433284773288, 37.588143322880526],
#       [126.90396681003595, 37.59227403419942],
#       [126.90303066177668, 37.609977911401344],
#       [126.91455481429648, 37.64150050996935],
#       [126.956473797387, 37.652480737339445],
#       [126.9738864128702, 37.62949634786888]]]}},
#   {'type': 'Feature',
#    'id': '노원구',
#    'properties': {'code': '11110',
#     'name': '노원구',
#     'name_eng': 'Nowon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0838752703195, 37.69359534202034],
#       [127.09706391309695, 37.686383719372294],
#       [127.09440766298717, 37.64713490473045],
#       [127.11326795855199, 37.639622905315925],
#       [127.10782277688129, 37.61804244241069],
#       [127.07351243825278, 37.61283660342313],
#       [127.05209373568619, 37.62164065487782],
#       [127.04358800895609, 37.62848931298715],
#       [127.05800075220091, 37.64318263878276],
#       [127.05288479710485, 37.68423857084347],
#       [127.0838752703195, 37.69359534202034]]]}},
#   {'type': 'Feature',
#    'id': '도봉구',
#    'properties': {'code': '11100',
#     'name': '도봉구',
#     'name_eng': 'Dobong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.05288479710485, 37.68423857084347],
#       [127.05800075220091, 37.64318263878276],
#       [127.04358800895609, 37.62848931298715],
#       [127.01465935892466, 37.64943687496812],
#       [127.02062116141389, 37.667173575971205],
#       [127.01039666042071, 37.681894589603594],
#       [127.01795099203432, 37.69824412775662],
#       [127.05288479710485, 37.68423857084347]]]}},
#   {'type': 'Feature',
#    'id': '강북구',
#    'properties': {'code': '11090',
#     'name': '강북구',
#     'name_eng': 'Gangbuk-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.99383903424, 37.676681761199085],
#       [127.01039666042071, 37.681894589603594],
#       [127.02062116141389, 37.667173575971205],
#       [127.01465935892466, 37.64943687496812],
#       [127.04358800895609, 37.62848931298715],
#       [127.05209373568619, 37.62164065487782],
#       [127.03892400992301, 37.609715611023816],
#       [127.0128154749523, 37.613652243470256],
#       [126.98672705513869, 37.63377641288196],
#       [126.9817452676551, 37.65209769387776],
#       [126.99383903424, 37.676681761199085]]]}},
#   {'type': 'Feature',
#    'id': '성북구',
#    'properties': {'code': '11080',
#     'name': '성북구',
#     'name_eng': 'Seongbuk-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.977175406416, 37.62859715400388],
#       [126.98672705513869, 37.63377641288196],
#       [127.0128154749523, 37.613652243470256],
#       [127.03892400992301, 37.609715611023816],
#       [127.05209373568619, 37.62164065487782],
#       [127.07351243825278, 37.61283660342313],
#       [127.07382707099227, 37.60401928986419],
#       [127.042705222094, 37.59239437593391],
#       [127.02527254528003, 37.57524616245249],
#       [126.99348293358314, 37.588565457216156],
#       [126.98879865992384, 37.6118927319756],
#       [126.977175406416, 37.62859715400388]]]}},
#   {'type': 'Feature',
#    'id': '중랑구',
#    'properties': {'code': '11070',
#     'name': '중랑구',
#     'name_eng': 'Jungnang-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.07351243825278, 37.61283660342313],
#       [127.10782277688129, 37.61804244241069],
#       [127.1201246020114, 37.60178457598188],
#       [127.10304174249214, 37.57076342290955],
#       [127.08068541280403, 37.56906425519017],
#       [127.07382707099227, 37.60401928986419],
#       [127.07351243825278, 37.61283660342313]]]}},
#   {'type': 'Feature',
#    'id': '동대문구',
#    'properties': {'code': '11060',
#     'name': '동대문구',
#     'name_eng': 'Dongdaemun-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02527254528003, 37.57524616245249],
#       [127.042705222094, 37.59239437593391],
#       [127.07382707099227, 37.60401928986419],
#       [127.08068541280403, 37.56906425519017],
#       [127.07421053024362, 37.55724769712085],
#       [127.05005601081567, 37.567577612590846],
#       [127.02547266349976, 37.568943552237734],
#       [127.02527254528003, 37.57524616245249]]]}},
#   {'type': 'Feature',
#    'id': '광진구',
#    'properties': {'code': '11050',
#     'name': '광진구',
#     'name_eng': 'Gwangjin-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.08068541280403, 37.56906425519017],
#       [127.10304174249214, 37.57076342290955],
#       [127.11519584981606, 37.557533180704915],
#       [127.1116764203608, 37.540669955324965],
#       [127.10087519791962, 37.524841220167055],
#       [127.0690698130372, 37.522279423505026],
#       [127.05867359288398, 37.52629974922568],
#       [127.07421053024362, 37.55724769712085],
#       [127.08068541280403, 37.56906425519017]]]}},
#   {'type': 'Feature',
#    'id': '성동구',
#    'properties': {'code': '11040',
#     'name': '성동구',
#     'name_eng': 'Seongdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.05005601081567, 37.567577612590846],
#       [127.07421053024362, 37.55724769712085],
#       [127.05867359288398, 37.52629974922568],
#       [127.02302831890559, 37.53231899582663],
#       [127.01070894177482, 37.54118048964762],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'id': '용산구',
#    'properties': {'code': '11030',
#     'name': '용산구',
#     'name_eng': 'Yongsan-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.01070894177482, 37.54118048964762],
#       [127.02302831890559, 37.53231899582663],
#       [127.01397119667513, 37.52503988289669],
#       [126.98223807916081, 37.509314966770326],
#       [126.95249990298159, 37.51722500741813],
#       [126.94566733083212, 37.526617542453366],
#       [126.96448570553055, 37.548705692021635],
#       [126.98752996903328, 37.55094818807139],
#       [127.01070894177482, 37.54118048964762]]]}},
#   {'type': 'Feature',
#    'id': '중구',
#    'properties': {'code': '11020',
#     'name': '중구',
#     'name_eng': 'Jung-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.01070894177482, 37.54118048964762],
#       [126.98752996903328, 37.55094818807139],
#       [126.96448570553055, 37.548705692021635],
#       [126.96358226710812, 37.55605635475154],
#       [126.96873633279075, 37.56313604690827],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'id': '종로구',
#    'properties': {'code': '11010',
#     'name': '종로구',
#     'name_eng': 'Jongno-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.977175406416, 37.62859715400388],
#       [126.98879865992384, 37.6118927319756],
#       [126.99348293358314, 37.588565457216156],
#       [127.02527254528003, 37.57524616245249],
#       [127.02547266349976, 37.568943552237734],
#       [126.96873633279075, 37.56313604690827],
#       [126.95565425846463, 37.576080790881456],
#       [126.9524752030572, 37.60508692737045],
#       [126.95427017006129, 37.622033431339425],
#       [126.9738864128702, 37.62949634786888]]]}}]}

# %%
crime_gu.head()
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구
# 강남구  600  14  10  3004  3885  87.166667   71.428571  100.000000  43.841545
# 강동구  170   7   3  1515  2224  84.117647  100.000000  100.000000  50.495050
# 강북구  188   7   8  1112  2122  71.808511  100.000000   75.000000  54.226619
# 강서구  269   6  11  1724  2619  91.449814   50.000000   81.818182  56.960557
# 관악구  352  10   9  2012  2643  86.647727  100.000000  100.000000  50.944334
#
#          폭력검거율
# 구
# 강남구  85.791506
# 강동구  84.127698
# 강북구  93.873704
# 강서구  85.108820
# 관악구  87.097995

# %%
crime_gu.reset_index().rename(columns = {"index": "구"})
crime_gu.rename_axis('구').reset_index()
crime_gu.index.name = '구'
crime_gu = crime_gu.reset_index()
crime_gu.head()
# Out:
#      구   강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 0  강남구  600  14  10  3004  3885  87.166667   71.428571  100.000000  43.841545
# 1  강동구  170   7   3  1515  2224  84.117647  100.000000  100.000000  50.495050
# 2  강북구  188   7   8  1112  2122  71.808511  100.000000   75.000000  54.226619
# 3  강서구  269   6  11  1724  2619  91.449814   50.000000   81.818182  56.960557
# 4  관악구  352  10   9  2012  2643  86.647727  100.000000  100.000000  50.944334
#
#        폭력검거율
# 0  85.791506
# 1  84.127698
# 2  93.873704
# 3  85.108820
# 4  87.097995

# %%
my_map = folium.Map(location = [37.5502, 126.982], zoom_start = 11)

folium.Choropleth(
    geo_data = geo_str,
    data = crime_gu, columns = ['구','살인'],
    key_on = 'feature.id', fill_color = 'PuRd',
    legend_name = 'Number of murder cases'
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f15d96e248d018b3c1f9c2c49c49551b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f15d96e248d018b3c1f9c2c49c49551b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f15d96e248d018b3c1f9c2c49c49551b = L.map(
#                 &quot;map_f15d96e248d018b3c1f9c2c49c49551b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c8b1acdad92b3c0668418b19164c584 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f15d96e248d018b3c1f9c2c49c49551b);
#
#
#             var choropleth_84947234a528388398372af25445c9b8 = L.featureGroup(
#                 {}
#             ).addTo(map_f15d96e248d018b3c1f9c2c49c49551b);
#
#
#         function geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7 = L.geoJson(null, {
#                 onEachFeature: geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_onEachFeature,
#
#                 style: geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_styler,
#         });
#
#         function geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_add (data) {
#             geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7
#                 .addData(data)
#                 .addTo(choropleth_84947234a528388398372af25445c9b8);
#         }
#             geo_json_d5d756db3c15fae9e54b3c2a5cc2b9f7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\u

# %%
my_map = folium.Map(location = [37.5502, 126.982], zoom_start = 11)

folium.Choropleth(
    geo_data = geo_str,
    data = crime_gu, columns = ['구','폭력'],
    key_on = 'feature.id', fill_color = 'PuRd',
    legend_name = 'Number of violence cases'
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c13cb561180c4e3aa092bd8e0fef60b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c13cb561180c4e3aa092bd8e0fef60b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c13cb561180c4e3aa092bd8e0fef60b6 = L.map(
#                 &quot;map_c13cb561180c4e3aa092bd8e0fef60b6&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_549a3b43595e377dc0216c5350712d47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c13cb561180c4e3aa092bd8e0fef60b6);
#
#
#             var choropleth_b3ebed2de6696d85f0623e40ef9c0b37 = L.featureGroup(
#                 {}
#             ).addTo(map_c13cb561180c4e3aa092bd8e0fef60b6);
#
#
#         function geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e = L.geoJson(null, {
#                 onEachFeature: geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_onEachFeature,
#
#                 style: geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_styler,
#         });
#
#         function geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_add (data) {
#             geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e
#                 .addData(data)
#                 .addTo(choropleth_b3ebed2de6696d85f0623e40ef9c0b37);
#         }
#             geo_json_2cdceaedf0307ce2c9c8a04b0df22f7e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485
